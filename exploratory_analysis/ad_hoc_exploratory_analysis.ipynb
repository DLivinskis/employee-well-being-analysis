# %%
from exploratory_analysis.descriptive_stats import DescriptiveStats
import pandas as pd

df = pd.read_csv("../raw_data/Impact_of_Remote_Work_on_Mental_Health.csv")

# %%
descriptive_stats = DescriptiveStats(data = df)

# %%
type(descriptive_stats.feature_vs_target())
# Out:
# dict

# %%
descriptive_stats.feature_vs_target().keys()
# Out:
# dict_keys(['Gender', 'Job_Role', 'Industry', 'Work_Location', 'Stress_Level', 'Mental_Health_Condition', 'Access_to_Mental_Health_Resources', 'Productivity_Change', 'Physical_Activity', 'Sleep_Quality', 'Region', 'Age', 'Years_of_Experience', 'Hours_Worked_Per_Week', 'Number_of_Virtual_Meetings', 'Work_Life_Balance_Rating', 'Social_Isolation_Rating', 'Company_Support_for_Remote_Work'])

# %%
descriptive_stats.feature_vs_target()["Gender"]
# Out:
# {'counts': Satisfaction_with_Remote_Work  Neutral  Satisfied  Unsatisfied
#  Gender
#  Female                             390        445          439
#  Male                               406        419          445
#  Non-binary                         420        401          393
#  Prefer not to say                  432        410          400,
#  'proportions': Satisfaction_with_Remote_Work   Neutral  Satisfied  Unsatisfied
#  Gender
#  Female                         0.306122   0.349294     0.344584
#  Male                           0.319685   0.329921     0.350394
#  Non-binary                     0.345964   0.330313     0.323723
#  Prefer not to say              0.347826   0.330113     0.322061,
#  'p_value': 0.22984947226295244,
#  'test': 'chi-square'}
